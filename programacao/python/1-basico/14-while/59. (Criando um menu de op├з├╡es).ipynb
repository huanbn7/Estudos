# %%
v1 = input("Primeiro valor: ")
while v1.isdigit() is False:
    v1 = input("ERRO, digite um numero: ")
v1 = int(v1)

v2 = input("Segundo valor: ")
while v2.isdigit() is False:
    v2 = input("ERRO, digite um numero: ")
v2 = int(v2)


a = 5

while a <= 5 :
    print(''' 
[1] Soma
[2] Multiplicação
[3] Maior
[4] Novos números
[5] Sair do pragrama ''')
    print() 
    
    j = input("Qual é a sua opção? ")
    while j.isdigit() is False:
        j = input("ERRO, digite um numero: ")
    j = int(j)
        
    
    if j == 1:
          print(f"\nA soma entre {v1} e {v2} = {v1+v2}")
          print("-="*16)
    
    if j == 2:
        print(f"\nA multiplicação entre {v1} e {v2} = {v1*v2}")
        print("-="*16)
    
    if j == 3:
        if v1>v2:
            print(f"\n{v1} é o maior")
        else:
            print(f"\n{v2} é o maior")
        print("-="*16)
    
    if j == 4:
        print()
        
        v1 = input("Primeiro valor: ")
        while v1.isdigit() is False:
            v1 = input("ERRO, digite um numero: ")
        v1 = int(v1)
        
        
        v2 = input("Segundo valor: ")
        while v2.isdigit() is False:
            v2 = input("ERRO, digite um numero: ")
        v2 = int(v2)

    
    if j == 5:
        a = a+1
    
    if j>5 or j<1:
        print("\nVocê digitou um número errado") 
      
   
        
        
    
print("O programa acabou")
# Out:
# Primeiro valor: 2
# Segundo valor: 3
#
# [1] Soma
# [2] Multiplicação
# [3] Maior
# [4] Novos números
# [5] Sair do pragrama
#
# Qual é a sua opção? s
# ERRO, digite um numero: 2
#
# A multiplicação entre 2 e 3 = 6
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# [1] Soma
# [2] Multiplicação
# [3] Maior
# [4] Novos números
# [5] Sair do pragrama
#
# Qual é a sua opção? 4
#
# Primeiro valor: a
# ERRO, digite um numero: 3
# Segundo valor: 1
#
# [1] Soma
# [2] Multiplicação
# [3] Maior
# [4] Novos números
# [5] Sair do pragrama
#
# Qual é a sua opção? 1
#
# A soma entre 3 e 1 = 4
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# [1] Soma
# [2] Multiplicação
# [3] Maior
# [4] Novos números
# [5] Sair do pragrama
